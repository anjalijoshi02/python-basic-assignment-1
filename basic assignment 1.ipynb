# %% [markdown]
# # Python Basic assignment - 1

# %% [markdown]
# #### Question 1:  In the below elements which of them are values or an expression? eg:- values can be integer or string and expressions will be mathematical operators.
#
# #### Answer:
# Expressions are :     'hello' , -87.8 , 6
# Operators are :         / , - , + , *

# %% [markdown]
# #### Question 2 : What is the difference between string and variable?
# #### Answer :
# A variable is used to store any kind of information and string is the type of value which is stored inside a variable.

# %% [markdown]
# #### Question 3 : Describe three different data types.
# #### Answer :
# ##### int data type :
# it used to store integer values
# #### float data type :
# it used to store flaoting (decimal) values
# #### complex data type :
# it is used to store complex numbers which consist of a real part and an imagnary part ie. real+ (imaginary)j.

# %%
## example of these data types are 
a=2
b=9.7
c=1+8j
print(a,type(a))
print(b,type(b))
print(c,type(c))
# Out:
# 2 <class 'int'>
# 9.7 <class 'float'>
# (1+8j) <class 'complex'>

# %% [markdown]
# #### Question 4 : What is an expression made up of? What do all expressions do?
# #### Answer :
# An expression is a combination of operators and operands that is interpreted to produce some value.

# %%
#example of an expression 
2+9/3*5    # this is an expression and the python interpreter evaluates this expression
# Out:
# 17.0

# %% [markdown]
# #### Question 5 : This assignment statements, like spam = 10. What is the difference between an expression and a statement?
# #### Answer:
# An expression is a combination of operators and operands that is interpreted to produce some value.
# When we type an expression, the interpreter basically evaluates the expression and returns the value of the expression
# for example : 3+10/5*3+45 is an expression
#
#
# A statement is a unit of code that has an effect, like creating a variable or displaying a value.When we type a statement, the interpreter executes it, which means that it does whatever the statement says. In general, statements don’t have values
# for example : variable declaration and assignment are statements because they do not return a value
#
# spam =10 is just an assignment statement , it assigns tha value 10 to the variable spam

# %% [markdown]
# #### Question 6 : After running the following code, what does the variable bacon contain?
# #### bacon =22
# #### bacon +1
#
# #### Answer :
# bacon contains 22 . bacon +1 is just a statement, it has no effect on original value of bacon and thus the value of bacon remains unaltered

# %% [markdown]
# #### Question 7 : What should the values of the following two terms be?      'spam'+'spamspam'     'spam'*3
# #### Answer:
# The result of both the terms is 'spamspamspam'.
# The first operation is string concatenation while the second operation is string multiplication.

# %% [markdown]
# #### Question 8 : Why is eggs a valid variable name while 100 is invalid?
# #### Answer :
# eggs is a valid name while 100 is not because python does not allow to name a variable with numbers.
# A variable name can start with a alphabet , underscore
# A variable should not be a reserved key

# %% [markdown]
# #### Question 9 : What three functions can be used to get the integer, floating-point number, or string version of a value?
# #### Answer :
# The int(),float(),and str() functions will evaluate to the integer,floating-point number,string version of the value passed to them.

# %% [markdown]
# #### Question 10 : Why does this expression cause an error? How can you fix it?    'I have eaten' + 99 + ' burritos'
# #### Answer :
# This expression causes an error bacuase python cannot concatenate string and an integer value .
# This error can be fixed by converting the integer into string and then concatenating these string.

# %%
print ('I have eaten '+str(99)+' burritos.')
# Out:
# I have eaten 99 burritos.
